# %%
import findspark
findspark.init('/home/ubuntu/spark-2.1.1-bin-hadoop2.7')
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('bank').getOrCreate()
bank = spark.read.csv('/home/ubuntu/Loan Defaulter.csv', header=True, inferSchema=True)

# %%
bank.createOrReplaceTempView("bank")
bank = spark.sql("SELECT * FROM bank WHERE TARGET = 0")
import pandas as pd
pd.DataFrame(bank.take(bank.count()), columns=bank.columns)
# Out:
#        SK_ID_CURR  TARGET CODE_GENDER  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0          100003       0           F             0        270000.000
# 1          100004       0           M             0         67500.000
# 2          100006       0           F             0        135000.000
# 3          100007       0           M             0        121500.000
# 4          100008       0           M             0         99000.000
# 5          100009       0           F             1        171000.000
# 6          100010       0           M             0        360000.000
# 7          100011       0           F             0        112500.000
# 8          100012       0           M             0        135000.000
# 9          100014       0           F             1        112500.000
# 10         100015       0           F             0         38419.155
# 11         100016       0           F             0         67500.000
# ...

# %%
bank.createOrReplaceTempView("bank")
bank = spark.sql("SELECT * FROM bank WHERE TARGET = 0 and CODE_GENDER='M'")
import pandas as pd
pd.DataFrame(bank.take(bank.count()), columns=bank.columns)
# Out:
#       SK_ID_CURR  TARGET CODE_GENDER  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0         100004       0           M             0           67500.0
# 1         100007       0           M             0          121500.0
# 2         100008       0           M             0           99000.0
# 3         100010       0           M             0          360000.0
# 4         100012       0           M             0          135000.0
# 5         100017       0           M             1          225000.0
# 6         100019       0           M             0          157500.0
# 7         100020       0           M             0          108000.0
# 8         100024       0           M             0          135000.0
# 9         100029       0           M             2          135000.0
# 10        100032       0           M             1          112500.0
# 11        100033       0           M             0          270000.0
# 12        100034       0           M             0           90000.0
# ...

# %%
bank.createOrReplaceTempView("bank")
bank = spark.sql("SELECT * FROM bank WHERE TARGET = 0 and CODE_GENDER='F'")
import pandas as pd
pd.DataFrame(bank.take(bank.count()), columns=bank.columns)
# Out:
#        SK_ID_CURR  TARGET CODE_GENDER  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0          100003       0           F             0        270000.000
# 1          100006       0           F             0        135000.000
# 2          100009       0           F             1        171000.000
# 3          100011       0           F             0        112500.000
# 4          100014       0           F             1        112500.000
# 5          100015       0           F             0         38419.155
# 6          100016       0           F             0         67500.000
# 7          100018       0           F             0        189000.000
# 8          100021       0           F             1         81000.000
# 9          100022       0           F             0        112500.000
# 10         100023       0           F             1         90000.000
# 11         100025       0           F             1        202500.000
# ...
